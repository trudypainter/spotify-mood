# %%
dir_list = os.listdir("daily-data")
dir_list.remove("")

for file in dir_list:
    filename = 'daily-data/' + file
    remove_duplicates(filename)
# Out:
# checking daily-data/2020-12-03.csv ....
# SONGS FOR  daily-data/2020-12-03.csv
# 0
# 0
# Completed!
#
# checking daily-data/2020-12-17.csv ....
# SONGS FOR  daily-data/2020-12-17.csv
# 40
# 40
# Completed!
#
# checking daily-data/2021-01-20.csv ....
# SONGS FOR  daily-data/2021-01-20.csv
# 24
# 24
# Completed!
#
# checking daily-data/2020-09-27.csv ....
# SONGS FOR  daily-data/2020-09-27.csv
# 40
# 40
# Completed!
#
# checking daily-data/2021-01-08.csv ....
# SONGS FOR  daily-data/2021-01-08.csv
# 33
# 33
# Completed!
#
# checking daily-data/2020-10-06.csv ....
# SONGS FOR  daily-data/2020-10-06.csv
# 63
# 63
# Completed!
#
# checking daily-data/2020-10-12.csv ....
# SONGS FOR  daily-data/2020-10-12.csv
# 92
# 92
# Completed!
#
# checking daily-data/2020-10-13.csv ....
# SONGS FOR  daily-data/2020-10-13.csv
# 57
# 57
# Completed!
#
# checking daily-data/2020-10-07.csv ....
# SONGS FOR  daily-data/2020-10-07.csv
# 46
# 46
# Completed!
#
# checking daily-data/2021-01-09.csv ....
# ...

# %%
dir_list = os.listdir("daily-data")
# Out:
# ['2020-12-03.csv',
#  '2020-12-17.csv',
#  '2021-01-20.csv',
#  '2020-09-27.csv',
#  '2021-01-08.csv',
#  '2020-10-06.csv',
#  '2020-10-12.csv',
#  '2020-10-13.csv',
#  '2020-10-07.csv',
#  '2021-01-09.csv',
#  '2020-09-26.csv',
#  '2021-01-21.csv',
#  '2020-12-16.csv',
#  '2020-12-02.csv',
#  '2020-12-14.csv',
#  '2020-12-28.csv',
#  '2020-09-24.csv',
#  '2020-09-30.csv',
#  '2021-01-23.csv',
#  '2020-09-18.csv',
#  '2020-10-11.csv',
#  '2020-10-05.csv',
#  '2020-10-04.csv',
#  '2020-10-10.csv',
#  '2020-09-19.csv',
#  '2021-01-22.csv',
#  '2020-09-25.csv',
#  '2020-12-29.csv',
#  '2020-12-01.csv',
#  '2020-12-15.csv',
#  '2020-12-11.csv',
#  '2020-12-05.csv',
#  '2020-09-09.csv',
#  '2020-09-21.csv',
#  '2021-01-26.csv',
#  '.DS_Store',
#  '2020-10-28.csv',
#  '2020-10-14.csv',
#  '2020-10-01.csv',
#  '2020-10-15.csv',
#  '2020-10-29.csv',
#  '2021-01-27.csv',
#  '2020-09-20.csv',
#  '2020-09-08.csv',
#  '2020-12-04.csv',
#  '2020-12-10.csv',
#  '2020-12-06.csv',
# ...

# %%
remove_duplicates("~/Desktop/personal-projects/spotify-mood/daily-data/2021-01-30.csv")
# Out:
# checking ~/Desktop/personal-projects/spotify-mood/daily-data/2021-01-30.csv ....
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-43f65b614994> in <module>
# ----> 1 remove_duplicates("~/Desktop/personal-projects/spotify-mood/daily-data/2021-01-30.csv")
#
# <ipython-input-24-ffce28b4b792> in remove_duplicates(filename)
#       7     print("checking", filename, "....")
#       8     # make tuple of songs
# ----> 9     with open(filename, mode='r') as csv_file:
#      10         csv_reader = csv.reader(csv_file, delimiter=',')
#      11
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Desktop/personal-projects/spotify-mood/daily-data/2021-01-30.csv'

# %%
cat ~/Desktop/personal-projects/spotify-mood/daily-data/2021-01-30.csv
# Out:
# https://i.scdn.co/image/ab67616d0000b273d53f7c72eccea3c4223dc9ce,Where U Are,Where U Are,Rina Sawayama,30tie454RN2304xzAu5Din,14:28,0.469,0.544,0.553,0.675
# https://i.scdn.co/image/ab67616d0000b2737d983e7bf67c2806218c2759,Ocean of Tears,Pang,Caroline Polachek,4RqBss578GNj4u9VYZK5u0,14:32,0.132,0.37,0.572,0.442
# https://i.scdn.co/image/ab67616d0000b2737d983e7bf67c2806218c2759,The Gate,Pang,Caroline Polachek,7zEFT8tRNy9B7I0F9OeNd0,14:36,0.103,0.174,0.176,0.314
# https://i.scdn.co/image/ab67616d0000b2737d983e7bf67c2806218c2759,Pang,Pang,Caroline Polachek,5bcJwBywjaz78KTf374PCb,14:40,0.547,0.638,0.707,0.681
# https://i.scdn.co/image/ab67616d0000b2737d983e7bf67c2806218c2759,New Normal,Pang,Caroline Polachek,3dPkaunRnlcwGiOTJpQGD1,14:45,0.488,0.567,0.688,0.483
# https://i.scdn.co/image/ab67616d0000b2737d983e7bf67c2806218c2759,Hit Me Where It Hurts,Pang,Caroline Polachek,2wcrQZ7ZJolYEfIaPP9yL4,14:48,0.261,0.502,0.732,0.523
# ...

# %%
#create empty csv files
import datetime

start_date = datetime.date(2021, 5, 9)
end_date = datetime.date(2021, 8, 2)
delta = datetime.timedelta(days=1)

while start_date <= end_date:
    print(start_date)
    f = open(str(start_date) + ".csv", "w")
    start_date += delta
# Out:
# 2021-05-09
# 2021-05-10
# 2021-05-11
# 2021-05-12
# 2021-05-13
# 2021-05-14
# 2021-05-15
# 2021-05-16
# 2021-05-17
# 2021-05-18
# 2021-05-19
# 2021-05-20
# 2021-05-21
# 2021-05-22
# 2021-05-23
# 2021-05-24
# 2021-05-25
# 2021-05-26
# 2021-05-27
# 2021-05-28
# 2021-05-29
# 2021-05-30
# 2021-05-31
# 2021-06-01
# 2021-06-02
# 2021-06-03
# 2021-06-04
# 2021-06-05
# 2021-06-06
# 2021-06-07
# 2021-06-08
# 2021-06-09
# 2021-06-10
# 2021-06-11
# 2021-06-12
# 2021-06-13
# 2021-06-14
# 2021-06-15
# 2021-06-16
# 2021-06-17
# 2021-06-18
# 2021-06-19
# 2021-06-20
# 2021-06-21
# 2021-06-22
# 2021-06-23
# 2021-06-24
# 2021-06-25
# 2021-06-26
# 2021-06-27
# 2021-06-28
# 2021-06-29
# 2021-06-30
# 2021-07-01
# 2021-07-02
# 2021-07-03
# 2021-07-04
# 2021-07-05
# 2021-07-06
# 2021-07-07
# 2021-07-08
# 2021-07-09
# 2021-07-10
# 2021-07-11
# 2021-07-12
# 2021-07-13
# 2021-07-14
# 2021-07-15
# 2021-07-16
# 2021-07-17
# 2021-07-18
# 2021-07-19
# 2021-07-20
# 2021-07-21
# 2021-07-22
# 2021-07-23
# ...
